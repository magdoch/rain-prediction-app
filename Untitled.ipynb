# %%
import sklearn
import pandas
import joblib

print("scikit-learn:", sklearn.__version__)
print("pandas:", pandas.__version__)
print("joblib:", joblib.__version__)
# Out:
# scikit-learn: 1.9.0
# pandas: 3.0.3
# joblib: 1.5.3

# %%
import sys
# !{sys.executable} -m pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.59.2-py3-none-any.whl.metadata (9.6 kB)
# Collecting altair!=5.4.0,!=5.4.1,<7,>=4.0 (from streamlit)
#   Downloading altair-6.2.2-py3-none-any.whl.metadata (11 kB)
# Collecting blinker<2,>=1.5.0 (from streamlit)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cachetools<8,>=5.5 (from streamlit)
#   Downloading cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Collecting click<9,>=7.0 (from streamlit)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading gitpython-3.1.51-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from streamlit) (2.5.1)
# Requirement already satisfied: packaging>=20 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<4,>=1.4.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from streamlit) (3.0.3)
# Collecting pillow<13,>=7.1.0 (from streamlit)
#   Downloading pillow-12.3.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (9.1 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.3-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting protobuf<8,>=3.20 (from streamlit)
#   Downloading protobuf-7.35.1-cp310-abi3-macosx_10_9_universal2.whl.metadata (595 bytes)
# Collecting pyarrow<25,>=7.0 (from streamlit)
#   Downloading pyarrow-24.0.0-cp312-cp312-macosx_12_0_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from streamlit) (2.32.5)
# Collecting tenacity<10,>=8.1.0 (from streamlit)
#   Downloading tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from streamlit) (4.15.0)
# Collecting starlette>=0.40.0 (from streamlit)
#   Downloading starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting uvicorn>=0.30.0 (from streamlit)
#   Downloading uvicorn-0.51.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting httptools>=0.6.3 (from streamlit)
#   Downloading httptools-0.8.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (3.5 kB)
# Requirement already satisfied: anyio>=4.0.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from streamlit) (4.12.0)
# Collecting python-multipart>=0.0.10 (from streamlit)
#   Downloading python_multipart-0.0.32-py3-none-any.whl.metadata (2.1 kB)
# Collecting websockets>=12.0.0 (from streamlit)
#   Downloading websockets-16.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.8 kB)
# Collecting itsdangerous>=2.1.2 (from streamlit)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.25.1)
# Requirement already satisfied: narwhals>=2.4.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.24.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit) (2025.11.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/envs/py312/lib/python3.12/site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Downloading streamlit-1.59.2-py3-none-any.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 1.4 MB/s  0:00:07eta 0:00:01
# Downloading altair-6.2.2-py3-none-any.whl (797 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.6/797.6 kB 1.0 MB/s  0:00:00 eta 0:00:01
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading cachetools-7.1.4-py3-none-any.whl (16 kB)
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Downloading gitpython-3.1.51-py3-none-any.whl (215 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading pillow-12.3.0-cp312-cp312-macosx_10_13_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 1.0 MB/s  0:00:05 eta 0:00:01
# Downloading protobuf-7.35.1-cp310-abi3-macosx_10_9_universal2.whl (433 kB)
# Downloading pyarrow-24.0.0-cp312-cp312-macosx_12_0_x86_64.whl (36.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.7/36.7 MB 1.0 MB/s  0:00:36m0:00:0100:01
# Downloading pydeck-0.9.3-py2.py3-none-any.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 789.5 kB/s  0:00:14m0:00:0100:01
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading httptools-0.8.0-cp312-cp312-macosx_10_13_universal2.whl (208 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading python_multipart-0.0.32-py3-none-any.whl (30 kB)
# Downloading starlette-1.3.1-py3-none-any.whl (73 kB)
# Downloading uvicorn-0.51.0-py3-none-any.whl (73 kB)
# Downloading websockets-16.1-cp312-cp312-macosx_10_13_x86_64.whl (177 kB)
# Installing collected packages: websockets, toml, tenacity, smmap, python-multipart, pyarrow, protobuf, pillow, itsdangerous, httptools, click, cachetools, blinker, uvicorn, starlette, pydeck, gitdb, gitpython, altair, streamlit
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20/20 [streamlit]20 [streamlit]
# Successfully installed altair-6.2.2 blinker-1.9.0 cachetools-7.1.4 click-8.4.2 gitdb-4.0.12 gitpython-3.1.51 httptools-0.8.0 itsdangerous-2.2.0 pillow-12.3.0 protobuf-7.35.1 pyarrow-24.0.0 pydeck-0.9.3 python-multipart-0.0.32 smmap-5.0.3 starlette-1.3.1 streamlit-1.59.2 tenacity-9.1.4 toml-0.10.2 uvicorn-0.51.0 websockets-16.1

# %%
import streamlit
print(streamlit.__version__)
# Out:
# 1.59.2
